# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('satgpa.csv')

# %%
data
# Out:
#      sex  sat_v  sat_m  sat_sum  hs_gpa  fy_gpa
# 0      1     65     62      127    3.40    3.18
# 1      2     58     64      122    4.00    3.33
# 2      2     56     60      116    3.75    3.25
# 3      1     42     53       95    3.75    2.42
# 4      1     55     52      107    4.00    2.63
# ..   ...    ...    ...      ...     ...     ...
# 995    2     50     50      100    3.70    2.19
# 996    1     54     54      108    3.30    1.50
# 997    1     56     58      114    3.50    3.17
# 998    1     55     65      120    2.30    1.94
# 999    1     49     44       93    2.70    2.38
#
# [1000 rows x 6 columns]

# %%
data.describe()
# Out:
#                sex       sat_v        sat_m      sat_sum       hs_gpa  \
# count  1000.000000  1000.00000  1000.000000  1000.000000  1000.000000
# mean      1.484000    48.93400    54.395000   103.329000     3.198100
# std       0.499994     8.23392     8.450111    14.287368     0.541647
# min       1.000000    24.00000    29.000000    53.000000     1.800000
# 25%       1.000000    43.00000    49.000000    93.000000     2.800000
# 50%       1.000000    49.00000    55.000000   103.000000     3.200000
# 75%       2.000000    54.00000    60.000000   113.000000     3.700000
# max       2.000000    76.00000    77.000000   144.000000     4.500000
#
#             fy_gpa
# count  1000.000000
# mean      2.467950
# std       0.740805
# min       0.000000
# 25%       1.980000
# 50%       2.465000
# 75%       3.020000
# max       4.000000

# %%
y = data['hs_gpa']
x1 = data['sat_sum']

# %%
plt.scatter(x1,y)
plt.xlabel('sat_sum',fontsize=20)
plt.ylabel('hs_gpa',fontsize=20)
plt.show()

# %%
x=sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 hs_gpa   R-squared:                       0.186
# Model:                            OLS   Adj. R-squared:                  0.185
# Method:                 Least Squares   F-statistic:                     227.4
# Date:                Thu, 18 Nov 2021   Prob (F-statistic):           1.90e-46
# Time:                        13:42:46   Log-Likelihood:                -702.66
# No. Observations:                1000   AIC:                             1409.
# Df Residuals:                     998   BIC:                             1419.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5106      0.113     13.372      0.000       1.289       1.732
# ...

# %%
plt.scatter(x1,y)
yhat= 0.0163*x1 + 1.5106
fig = plt.plot(x1,yhat, lw=4, c='orange', label = 'regressionl line')
plt.xlabel('sat_sum',fontsize=20)
plt.ylabel('hs_gpa',fontsize=20)
plt.show()
